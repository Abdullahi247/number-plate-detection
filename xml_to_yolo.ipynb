# %%
import os
import xml.etree.ElementTree as ET

# Class name to class ID
class_map = {'licence': 0}  # Add more classes if needed

def convert_voc_to_yolo(xml_folder, output_folder):
    # Make sure output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Go through each XML file
    for xml_file in os.listdir(xml_folder):
        if not xml_file.endswith('.xml'):
            continue

        tree = ET.parse(os.path.join(xml_folder, xml_file))
        root = tree.getroot()

        # Get image size
        width = int(root.find('size/width').text)
        height = int(root.find('size/height').text)

        yolo_labels = []

        # Go through each object in the image
        for obj in root.findall('object'):
            class_name = obj.find('name').text
            if class_name not in class_map:
                print(f"Skipping unknown class: {class_name}")
                continue

            class_id = class_map[class_name]

            # Get bounding box and normalize
            bndbox = obj.find('bndbox')
            xmin = int(bndbox.find('xmin').text)
            xmax = int(bndbox.find('xmax').text)
            ymin = int(bndbox.find('ymin').text)
            ymax = int(bndbox.find('ymax').text)

            cx = (xmin + xmax) / 2 / width
            cy = (ymin + ymax) / 2 / height
            w = (xmax - xmin) / width
            h = (ymax - ymin) / height

            # Format: class_id cx cy w h
            yolo_labels.append(f"{class_id} {cx:.6f} {cy:.6f} {w:.6f} {h:.6f}")

        # Write YOLO label file
        txt_filename = os.path.splitext(xml_file)[0] + '.txt'
        txt_path = os.path.join(output_folder, txt_filename)

        with open(txt_path, 'w') as f:
            f.write('\n'.join(yolo_labels))

        print(f"Converted {xml_file} → {txt_filename}")

# %%
convert_voc_to_yolo(
    xml_folder='datasets/annotations',
    output_folder='datasets/labels/train'
)
# Out:
# Converted Cars213.xml → Cars213.txt
# Converted Cars207.xml → Cars207.txt
# Converted Cars398.xml → Cars398.txt
# Converted Cars367.xml → Cars367.txt
# Converted Cars401.xml → Cars401.txt
# Converted Cars415.xml → Cars415.txt
# Converted Cars373.xml → Cars373.txt
# Converted Cars429.xml → Cars429.txt
# Converted Cars47.xml → Cars47.txt
# Converted Cars53.xml → Cars53.txt
# Converted Cars165.xml → Cars165.txt
# Converted Cars171.xml → Cars171.txt
# Converted Cars159.xml → Cars159.txt
# Converted Cars84.xml → Cars84.txt
# Converted Cars90.xml → Cars90.txt
# Converted Cars91.xml → Cars91.txt
# Converted Cars85.xml → Cars85.txt
# Converted Cars158.xml → Cars158.txt
# Converted Cars170.xml → Cars170.txt
# Converted Cars164.xml → Cars164.txt
# Converted Cars52.xml → Cars52.txt
# Converted Cars46.xml → Cars46.txt
# Converted Cars428.xml → Cars428.txt
# Converted Cars414.xml → Cars414.txt
# Converted Cars372.xml → Cars372.txt
# Converted Cars366.xml → Cars366.txt
# Converted Cars400.xml → Cars400.txt
# Converted Cars399.xml → Cars399.txt
# Converted Cars206.xml → Cars206.txt
# Converted Cars212.xml → Cars212.txt
# Converted Cars204.xml → Cars204.txt
# Converted Cars210.xml → Cars210.txt
# Converted Cars238.xml → Cars238.txt
# Converted Cars370.xml → Cars370.txt
# Converted Cars416.xml → Cars416.txt
# Converted Cars402.xml → Cars402.txt
# Converted Cars364.xml → Cars364.txt
# Converted Cars358.xml → Cars358.txt
# Converted Cars78.xml → Cars78.txt
# Converted Cars50.xml → Cars50.txt
# Converted Cars199.xml → Cars199.txt
# Converted Cars44.xml → Cars44.txt
# Converted Cars172.xml → Cars172.txt
# Converted Cars166.xml → Cars166.txt
# Converted Cars93.xml → Cars93.txt
# Converted Cars87.xml → Cars87.txt
# Converted Cars86.xml → Cars86.txt
# Converted Cars92.xml → Cars92.txt
# Converted Cars167.xml → Cars167.txt
# Converted Cars173.xml → Cars173.txt
# Converted Cars45.xml → Cars45.txt
# Converted Cars198.xml → Cars198.txt
# Converted Cars51.xml → Cars51.txt
# Converted Cars79.xml → Cars79.txt
# Converted Cars359.xml → Cars359.txt
# Converted Cars403.xml → Cars403.txt
# Converted Cars365.xml → Cars365.txt
# Converted Cars371.xml → Cars371.txt
# Converted Cars417.xml → Cars417.txt
# Converted Cars239.xml → Cars239.txt
# Converted Cars211.xml → Cars211.txt
# Converted Cars205.xml → Cars205.txt
# Converted Cars229.xml → Cars229.txt
# Converted Cars201.xml → Cars201.txt
# Converted Cars215.xml → Cars215.txt
# Converted Cars349.xml → Cars349.txt
# Converted Cars413.xml → Cars413.txt
# Converted Cars375.xml → Cars375.txt
# Converted Cars361.xml → Cars361.txt
# Converted Cars407.xml → Cars407.txt
# Converted Cars55.xml → Cars55.txt
# Converted Cars188.xml → Cars188.txt
# Converted Cars41.xml → Cars41.txt
# Converted Cars69.xml → Cars69.txt
# Converted Cars96.xml → Cars96.txt
# Converted Cars82.xml → Cars82.txt
# Converted Cars177.xml → Cars177.txt
# Converted Cars163.xml → Cars163.txt
# Converted Cars162.xml → Cars162.txt
# Converted Cars176.xml → Cars176.txt
# Converted Cars83.xml → Cars83.txt
# Converted Cars97.xml → Cars97.txt
# Converted Cars68.xml → Cars68.txt
# Converted Cars40.xml → Cars40.txt
# Converted Cars189.xml → Cars189.txt
# Converted Cars54.xml → Cars54.txt
# Converted Cars360.xml → Cars360.txt
# Converted Cars406.xml → Cars406.txt
# Converted Cars412.xml → Cars412.txt
# Converted Cars374.xml → Cars374.txt
# Converted Cars348.xml → Cars348.txt
# Converted Cars214.xml → Cars214.txt
# Converted Cars200.xml → Cars200.txt
# Converted Cars228.xml → Cars228.txt
# Converted Cars216.xml → Cars216.txt
# Converted Cars202.xml → Cars202.txt
# Converted Cars389.xml → Cars389.txt
# Converted Cars404.xml → Cars404.txt
# Converted Cars362.xml → Cars362.txt
# Converted Cars376.xml → Cars376.txt
# Converted Cars410.xml → Cars410.txt
# Converted Cars42.xml → Cars42.txt
# Converted Cars56.xml → Cars56.txt
# Converted Cars81.xml → Cars81.txt
# Converted Cars95.xml → Cars95.txt
# Converted Cars148.xml → Cars148.txt
# Converted Cars160.xml → Cars160.txt
# Converted Cars174.xml → Cars174.txt
# Converted Cars175.xml → Cars175.txt
# Converted Cars161.xml → Cars161.txt
# Converted Cars149.xml → Cars149.txt
# Converted Cars94.xml → Cars94.txt
# Converted Cars80.xml → Cars80.txt
# Converted Cars57.xml → Cars57.txt
# Converted Cars43.xml → Cars43.txt
# Converted Cars377.xml → Cars377.txt
# Converted Cars411.xml → Cars411.txt
# Converted Cars405.xml → Cars405.txt
# Converted Cars363.xml → Cars363.txt
# Converted Cars388.xml → Cars388.txt
# Converted Cars203.xml → Cars203.txt
# Converted Cars217.xml → Cars217.txt
# Converted Cars270.xml → Cars270.txt
# Converted Cars264.xml → Cars264.txt
# Converted Cars258.xml → Cars258.txt
# Converted Cars304.xml → Cars304.txt
# Converted Cars310.xml → Cars310.txt
# Converted Cars338.xml → Cars338.txt
# Converted Cars18.xml → Cars18.txt
# Converted Cars24.xml → Cars24.txt
# Converted Cars30.xml → Cars30.txt
# Converted Cars106.xml → Cars106.txt
# Converted Cars3.xml → Cars3.txt
# Converted Cars112.xml → Cars112.txt
# Converted Cars113.xml → Cars113.txt
# Converted Cars2.xml → Cars2.txt
# Converted Cars107.xml → Cars107.txt
# Converted Cars31.xml → Cars31.txt
# Converted Cars25.xml → Cars25.txt
# Converted Cars19.xml → Cars19.txt
# Converted Cars339.xml → Cars339.txt
# Converted Cars311.xml → Cars311.txt
# Converted Cars305.xml → Cars305.txt
# Converted Cars259.xml → Cars259.txt
# Converted Cars265.xml → Cars265.txt
# Converted Cars271.xml → Cars271.txt
# Converted Cars298.xml → Cars298.txt
# Converted Cars267.xml → Cars267.txt
# Converted Cars273.xml → Cars273.txt
# Converted Cars313.xml → Cars313.txt
# Converted Cars307.xml → Cars307.txt
# Converted Cars33.xml → Cars33.txt
# Converted Cars27.xml → Cars27.txt
# Converted Cars111.xml → Cars111.txt
# Converted Cars105.xml → Cars105.txt
# Converted Cars0.xml → Cars0.txt
# Converted Cars139.xml → Cars139.txt
# Converted Cars138.xml → Cars138.txt
# Converted Cars1.xml → Cars1.txt
# Converted Cars104.xml → Cars104.txt
# Converted Cars110.xml → Cars110.txt
# Converted Cars26.xml → Cars26.txt
# Converted Cars32.xml → Cars32.txt
# Converted Cars306.xml → Cars306.txt
# Converted Cars312.xml → Cars312.txt
# Converted Cars272.xml → Cars272.txt
# Converted Cars266.xml → Cars266.txt
# Converted Cars299.xml → Cars299.txt
# Converted Cars289.xml → Cars289.txt
# Converted Cars262.xml → Cars262.txt
# Converted Cars276.xml → Cars276.txt
# Converted Cars316.xml → Cars316.txt
# Converted Cars302.xml → Cars302.txt
# Converted Cars36.xml → Cars36.txt
# Converted Cars22.xml → Cars22.txt
# Converted Cars128.xml → Cars128.txt
# Converted Cars114.xml → Cars114.txt
# Converted Cars100.xml → Cars100.txt
# Converted Cars5.xml → Cars5.txt
# Converted Cars4.xml → Cars4.txt
# Converted Cars101.xml → Cars101.txt
# Converted Cars115.xml → Cars115.txt
# Converted Cars129.xml → Cars129.txt
# Converted Cars23.xml → Cars23.txt
# Converted Cars37.xml → Cars37.txt
# Converted Cars303.xml → Cars303.txt
# Converted Cars317.xml → Cars317.txt
# Converted Cars277.xml → Cars277.txt
# Converted Cars263.xml → Cars263.txt
# Converted Cars288.xml → Cars288.txt
# Converted Cars249.xml → Cars249.txt
# Converted Cars275.xml → Cars275.txt
# Converted Cars261.xml → Cars261.txt
# Converted Cars329.xml → Cars329.txt
# Converted Cars301.xml → Cars301.txt
# Converted Cars315.xml → Cars315.txt
# Converted Cars21.xml → Cars21.txt
# Converted Cars35.xml → Cars35.txt
# Converted Cars103.xml → Cars103.txt
# Converted Cars6.xml → Cars6.txt
# Converted Cars117.xml → Cars117.txt
# Converted Cars116.xml → Cars116.txt
# Converted Cars7.xml → Cars7.txt
# Converted Cars102.xml → Cars102.txt
# Converted Cars34.xml → Cars34.txt
# Converted Cars20.xml → Cars20.txt
# Converted Cars314.xml → Cars314.txt
# Converted Cars300.xml → Cars300.txt
# Converted Cars328.xml → Cars328.txt
# Converted Cars260.xml → Cars260.txt
# Converted Cars274.xml → Cars274.txt
# Converted Cars248.xml → Cars248.txt
# Converted Cars292.xml → Cars292.txt
# Converted Cars286.xml → Cars286.txt
# Converted Cars251.xml → Cars251.txt
# Converted Cars245.xml → Cars245.txt
# Converted Cars279.xml → Cars279.txt
# Converted Cars325.xml → Cars325.txt
# Converted Cars331.xml → Cars331.txt
# Converted Cars319.xml → Cars319.txt
# Converted Cars39.xml → Cars39.txt
# Converted Cars11.xml → Cars11.txt
# Converted Cars127.xml → Cars127.txt
# Converted Cars133.xml → Cars133.txt
# Converted Cars132.xml → Cars132.txt
# Converted Cars126.xml → Cars126.txt
# Converted Cars10.xml → Cars10.txt
# Converted Cars38.xml → Cars38.txt
# Converted Cars318.xml → Cars318.txt
# Converted Cars330.xml → Cars330.txt
# Converted Cars324.xml → Cars324.txt
# Converted Cars278.xml → Cars278.txt
# Converted Cars244.xml → Cars244.txt
# Converted Cars250.xml → Cars250.txt
# Converted Cars287.xml → Cars287.txt
# Converted Cars293.xml → Cars293.txt
# Converted Cars285.xml → Cars285.txt
# Converted Cars291.xml → Cars291.txt
# Converted Cars246.xml → Cars246.txt
# Converted Cars252.xml → Cars252.txt
# Converted Cars332.xml → Cars332.txt
# Converted Cars326.xml → Cars326.txt
# Converted Cars12.xml → Cars12.txt
# Converted Cars130.xml → Cars130.txt
# Converted Cars124.xml → Cars124.txt
# Converted Cars9.xml → Cars9.txt
# Converted Cars118.xml → Cars118.txt
# Converted Cars119.xml → Cars119.txt
# Converted Cars8.xml → Cars8.txt
# Converted Cars125.xml → Cars125.txt
# Converted Cars131.xml → Cars131.txt
# Converted Cars13.xml → Cars13.txt
# Converted Cars327.xml → Cars327.txt
# Converted Cars333.xml → Cars333.txt
# Converted Cars253.xml → Cars253.txt
# Converted Cars247.xml → Cars247.txt
# Converted Cars290.xml → Cars290.txt
# Converted Cars284.xml → Cars284.txt
# Converted Cars280.xml → Cars280.txt
# Converted Cars294.xml → Cars294.txt
# Converted Cars243.xml → Cars243.txt
# Converted Cars257.xml → Cars257.txt
# Converted Cars337.xml → Cars337.txt
# Converted Cars323.xml → Cars323.txt
# Converted Cars17.xml → Cars17.txt
# Converted Cars109.xml → Cars109.txt
# Converted Cars135.xml → Cars135.txt
# Converted Cars121.xml → Cars121.txt
# Converted Cars120.xml → Cars120.txt
# Converted Cars134.xml → Cars134.txt
# Converted Cars108.xml → Cars108.txt
# Converted Cars16.xml → Cars16.txt
# Converted Cars322.xml → Cars322.txt
# Converted Cars336.xml → Cars336.txt
# Converted Cars256.xml → Cars256.txt
# Converted Cars242.xml → Cars242.txt
# Converted Cars295.xml → Cars295.txt
# Converted Cars281.xml → Cars281.txt
# Converted Cars297.xml → Cars297.txt
# Converted Cars283.xml → Cars283.txt
# Converted Cars268.xml → Cars268.txt
# Converted Cars254.xml → Cars254.txt
# Converted Cars240.xml → Cars240.txt
# Converted Cars308.xml → Cars308.txt
# Converted Cars320.xml → Cars320.txt
# Converted Cars334.xml → Cars334.txt
# Converted Cars14.xml → Cars14.txt
# Converted Cars28.xml → Cars28.txt
# Converted Cars122.xml → Cars122.txt
# Converted Cars136.xml → Cars136.txt
# Converted Cars137.xml → Cars137.txt
# Converted Cars123.xml → Cars123.txt
# Converted Cars29.xml → Cars29.txt
# Converted Cars15.xml → Cars15.txt
# Converted Cars335.xml → Cars335.txt
# Converted Cars321.xml → Cars321.txt
# Converted Cars309.xml → Cars309.txt
# Converted Cars241.xml → Cars241.txt
# Converted Cars255.xml → Cars255.txt
# Converted Cars269.xml → Cars269.txt
# Converted Cars282.xml → Cars282.txt
# Converted Cars296.xml → Cars296.txt
# Converted Cars232.xml → Cars232.txt
# Converted Cars226.xml → Cars226.txt
# Converted Cars385.xml → Cars385.txt
# Converted Cars391.xml → Cars391.txt
# Converted Cars346.xml → Cars346.txt
# Converted Cars420.xml → Cars420.txt
# Converted Cars352.xml → Cars352.txt
# Converted Cars408.xml → Cars408.txt
# Converted Cars187.xml → Cars187.txt
# Converted Cars193.xml → Cars193.txt
# Converted Cars66.xml → Cars66.txt
# Converted Cars72.xml → Cars72.txt
# Converted Cars144.xml → Cars144.txt
# Converted Cars99.xml → Cars99.txt
# Converted Cars150.xml → Cars150.txt
# Converted Cars178.xml → Cars178.txt
# Converted Cars179.xml → Cars179.txt
# Converted Cars151.xml → Cars151.txt
# Converted Cars98.xml → Cars98.txt
# Converted Cars145.xml → Cars145.txt
# Converted Cars73.xml → Cars73.txt
# Converted Cars67.xml → Cars67.txt
# Converted Cars192.xml → Cars192.txt
# Converted Cars186.xml → Cars186.txt
# Converted Cars409.xml → Cars409.txt
# Converted Cars353.xml → Cars353.txt
# Converted Cars347.xml → Cars347.txt
# Converted Cars421.xml → Cars421.txt
# Converted Cars390.xml → Cars390.txt
# Converted Cars384.xml → Cars384.txt
# Converted Cars227.xml → Cars227.txt
# Converted Cars233.xml → Cars233.txt
# Converted Cars225.xml → Cars225.txt
# Converted Cars231.xml → Cars231.txt
# Converted Cars219.xml → Cars219.txt
# Converted Cars392.xml → Cars392.txt
# Converted Cars386.xml → Cars386.txt
# Converted Cars351.xml → Cars351.txt
# Converted Cars423.xml → Cars423.txt
# Converted Cars345.xml → Cars345.txt
# Converted Cars379.xml → Cars379.txt
# Converted Cars190.xml → Cars190.txt
# Converted Cars184.xml → Cars184.txt
# Converted Cars59.xml → Cars59.txt
# Converted Cars71.xml → Cars71.txt
# Converted Cars65.xml → Cars65.txt
# Converted Cars153.xml → Cars153.txt
# Converted Cars147.xml → Cars147.txt
# Converted Cars146.xml → Cars146.txt
# Converted Cars152.xml → Cars152.txt
# Converted Cars64.xml → Cars64.txt
# Converted Cars70.xml → Cars70.txt
# Converted Cars58.xml → Cars58.txt
# Converted Cars185.xml → Cars185.txt
# Converted Cars191.xml → Cars191.txt
# Converted Cars378.xml → Cars378.txt
# Converted Cars422.xml → Cars422.txt
# Converted Cars344.xml → Cars344.txt
# Converted Cars350.xml → Cars350.txt
# Converted Cars387.xml → Cars387.txt
# Converted Cars393.xml → Cars393.txt
# Converted Cars218.xml → Cars218.txt
# Converted Cars230.xml → Cars230.txt
# Converted Cars224.xml → Cars224.txt
# Converted Cars208.xml → Cars208.txt
# Converted Cars220.xml → Cars220.txt
# Converted Cars234.xml → Cars234.txt
# Converted Cars397.xml → Cars397.txt
# Converted Cars383.xml → Cars383.txt
# Converted Cars368.xml → Cars368.txt
# Converted Cars432.xml → Cars432.txt
# Converted Cars354.xml → Cars354.txt
# Converted Cars340.xml → Cars340.txt
# Converted Cars426.xml → Cars426.txt
# Converted Cars74.xml → Cars74.txt
# Converted Cars60.xml → Cars60.txt
# Converted Cars48.xml → Cars48.txt
# Converted Cars195.xml → Cars195.txt
# Converted Cars181.xml → Cars181.txt
# Converted Cars156.xml → Cars156.txt
# Converted Cars142.xml → Cars142.txt
# Converted Cars143.xml → Cars143.txt
# Converted Cars157.xml → Cars157.txt
# Converted Cars180.xml → Cars180.txt
# Converted Cars194.xml → Cars194.txt
# Converted Cars49.xml → Cars49.txt
# Converted Cars61.xml → Cars61.txt
# Converted Cars75.xml → Cars75.txt
# Converted Cars341.xml → Cars341.txt
# Converted Cars427.xml → Cars427.txt
# Converted Cars355.xml → Cars355.txt
# Converted Cars369.xml → Cars369.txt
# Converted Cars382.xml → Cars382.txt
# Converted Cars396.xml → Cars396.txt
# Converted Cars235.xml → Cars235.txt
# Converted Cars221.xml → Cars221.txt
# Converted Cars209.xml → Cars209.txt
# Converted Cars237.xml → Cars237.txt
# Converted Cars223.xml → Cars223.txt
# Converted Cars380.xml → Cars380.txt
# Converted Cars394.xml → Cars394.txt
# Converted Cars419.xml → Cars419.txt
# Converted Cars425.xml → Cars425.txt
# Converted Cars343.xml → Cars343.txt
# Converted Cars357.xml → Cars357.txt
# Converted Cars431.xml → Cars431.txt
# Converted Cars63.xml → Cars63.txt
# Converted Cars77.xml → Cars77.txt
# Converted Cars182.xml → Cars182.txt
# Converted Cars196.xml → Cars196.txt
# Converted Cars169.xml → Cars169.txt
# Converted Cars141.xml → Cars141.txt
# Converted Cars88.xml → Cars88.txt
# Converted Cars155.xml → Cars155.txt
# Converted Cars154.xml → Cars154.txt
# Converted Cars89.xml → Cars89.txt
# Converted Cars140.xml → Cars140.txt
# Converted Cars168.xml → Cars168.txt
# Converted Cars197.xml → Cars197.txt
# Converted Cars183.xml → Cars183.txt
# Converted Cars76.xml → Cars76.txt
# Converted Cars62.xml → Cars62.txt
# Converted Cars356.xml → Cars356.txt
# Converted Cars430.xml → Cars430.txt
# Converted Cars424.xml → Cars424.txt
# Converted Cars342.xml → Cars342.txt
# Converted Cars418.xml → Cars418.txt
# Converted Cars395.xml → Cars395.txt
# Converted Cars381.xml → Cars381.txt
# Converted Cars222.xml → Cars222.txt
# Converted Cars236.xml → Cars236.txt
